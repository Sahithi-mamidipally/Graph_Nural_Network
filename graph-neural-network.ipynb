# %%
#pip install torch_geometric

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import math
import json
import os
import collections

import matplotlib.pyplot as plt
import matplotlib
import matplotlib.animation as animation
import itertools
from itertools import combinations 


import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler 

from sklearn import metrics
 
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import torch_geometric
from torch_geometric.data import Data
from torch_geometric.data import DataLoader as DataLoaderGraph
from torch_geometric.data import Dataset as DatasetGraph
from torch_geometric.data import Batch as BatchGraph

#from torch_geometric.transforms import AddTrainValTestMask as masking

from torch_geometric.nn import GCNConv, BatchNorm, SAGEConv, SGConv, ChebConv
from torch_geometric.utils.convert import to_networkx

import networkx as nx

# %%
with open("musae_git_features.json") as json_data:
    data_raw = json.load(json_data)

edges=pd.read_csv("musae_git_edges.csv")
target_df=pd.read_csv("musae_git_target.csv")#.to_numpy()[:,2]

# %%
print("5 top nodes labels")
print(target_df.head(5).to_markdown())
print()
print("5 last nodes")
print(target_df.tail(5).to_markdown())
# Out:
# 5 top nodes labels
# |    |   id | name         |   ml_target |
# |---:|-----:|:-------------|------------:|
# |  0 |    0 | Eiryyy       |           0 |
# |  1 |    1 | shawflying   |           0 |
# |  2 |    2 | JpMCarrilho  |           1 |
# |  3 |    3 | SuhwanCha    |           0 |
# |  4 |    4 | sunilangadi2 |           1 |
#
# 5 last nodes
# |       |    id | name           |   ml_target |
# |------:|------:|:---------------|------------:|
# | 37695 | 37695 | shawnwanderson |           1 |
# | 37696 | 37696 | kris-ipeh      |           0 |
# | 37697 | 37697 | qpautrat       |           0 |
# | 37698 | 37698 | Injabie3       |           1 |
# | 37699 | 37699 | caseycavanagh  |           0 |

# %%
feats=[]
feat_counts=[]
for i in range(len(data_raw)):
    feat_counts+=[len(data_raw[str(i)])]
    feats+=data_raw[str(i)]

print("5 top nodes labels")
print(target_df.head(5).to_markdown())
print()
print("5 last nodes")
print(target_df.tail(5).to_markdown())
# Out:
# 5 top nodes labels
# |    |   id | name         |   ml_target |
# |---:|-----:|:-------------|------------:|
# |  0 |    0 | Eiryyy       |           0 |
# |  1 |    1 | shawflying   |           0 |
# |  2 |    2 | JpMCarrilho  |           1 |
# |  3 |    3 | SuhwanCha    |           0 |
# |  4 |    4 | sunilangadi2 |           1 |
#
# 5 last nodes
# |       |    id | name           |   ml_target |
# |------:|------:|:---------------|------------:|
# | 37695 | 37695 | shawnwanderson |           1 |
# | 37696 | 37696 | kris-ipeh      |           0 |
# | 37697 | 37697 | qpautrat       |           0 |
# | 37698 | 37698 | Injabie3       |           1 |
# | 37699 | 37699 | caseycavanagh  |           0 |

# %%
plt.hist(target_df.ml_target,bins=4,);
plt.title("Classes distribution")
plt.show()

plt.hist(feat_counts,bins=20)
plt.title("Number of features per graph distribution")
plt.show()

plt.hist(feats,bins=50)
plt.title("Features distribution")
plt.show()

# %%
counter=collections.Counter(feats)
print(list(counter.keys())[:10])
print(list(counter.values())[:10])
print(list(counter.keys())[-10:])
print(list(counter.values())[-10:])
#data_encoded
# Out:
# [1574, 3773, 3571, 2672, 2478, 2534, 3129, 3077, 1171, 2045]
# [5045, 12726, 2486, 298, 165, 510, 22075, 28188, 24958, 21449]
# [936, 172, 875, 3548, 2745, 793, 1941, 464, 2616, 3124]
# [1, 2, 1, 2, 1, 1, 1, 1, 1, 1]

# %%
def encode_data(light=False,n=60):
    if light==True:
        nodes_included=n
    elif light==False:
        nodes_included=len(data_raw)
    
    data_encoded={}
    for i in range(nodes_included):# 
        one_hot_feat=np.array([0]*(max(feats)+1))
        this_feat=data_raw[str(i)]
        one_hot_feat[this_feat]=1
        data_encoded[str(i)]=list(one_hot_feat)
    
    if light==True:
        sparse_feat_matrix=np.zeros((1,max(feats)+1))
        for j in range(nodes_included):
            temp=np.array(data_encoded[str(j)]).reshape(1,-1)
            sparse_feat_matrix=np.concatenate((sparse_feat_matrix,temp),axis=0)
        sparse_feat_matrix=sparse_feat_matrix[1:,:]
        return(data_encoded,sparse_feat_matrix)
    elif light==False:
        return(data_encoded, None)

# %%
data_encoded_vis,sparse_feat_matrix_vis=encode_data(light=True,n=60)
plt.figure(figsize=(25,25));
plt.imshow(sparse_feat_matrix_vis[:,:250],cmap='Greys');
#plt.grid()

# %%
def construct_graph(data_encoded,light=False):
    node_features_list=list(data_encoded.values())
    node_features=torch.tensor(node_features_list)
    node_labels=torch.tensor(target_df['ml_target'].values)
    edges_list=edges.values.tolist()
    edge_index01=torch.tensor(edges_list, dtype = torch.long).T
    edge_index02=torch.zeros(edge_index01.shape, dtype = torch.long)#.T
    edge_index02[0,:]=edge_index01[1,:]
    edge_index02[1,:]=edge_index01[0,:]
    edge_index0=torch.cat((edge_index01,edge_index02),axis=1)
    g = Data(x=node_features, y=node_labels, edge_index=edge_index0)
    g_light = Data(x=node_features[:,0:2],
                     y=node_labels   ,
                     edge_index=edge_index0[:,:55])
    if light:
        return(g_light)
    else:
        return(g)

# %%
#g_top_draw = Data(x=node_features, y=node_labels, edge_index=edge_index0)

def draw_graph(data0):
    #node_labels=data0.y
    if data0.num_nodes>100:
        print("This is a big graph, can not plot...")
        return
        
    else:
        data_nx = to_networkx(data0)
        node_colors=data0.y[list(data_nx.nodes)]
        pos= nx.spring_layout(data_nx,scale =1)
        plt.figure(figsize=(12,8))
        nx.draw(data_nx, pos,  cmap=plt.get_cmap('Set1'),
                node_color =node_colors,node_size=600,connectionstyle="angle3",
                width =1, with_labels = False, edge_color = 'k', arrowstyle = "-")

# %%
g_sample=construct_graph(data_encoded=data_encoded_vis,light=True)
draw_graph(g_sample)

# %%
data_encoded,_=encode_data(light=False)

# %%
g=construct_graph(data_encoded=data_encoded,light=False)

# %%
print(g)
# Out:
# Data(x=[37700, 4005], edge_index=[2, 578006], y=[37700])

# %%
import torch_geometric.transforms as T

# %%
import torch_geometric.transforms as T
msk=T.RandomNodeSplit(split="train_rest", num_splits = 1, num_val = 0.3, num_test= 0.6)
g=msk(g)
print(g)
print()
print("training samples",torch.sum(g.train_mask).item())
print("validation samples",torch.sum(g.val_mask ).item())
print("test samples",torch.sum(g.test_mask ).item())
# Out:
# Data(x=[37700, 4005], edge_index=[2, 578006], y=[37700], train_mask=[37700], val_mask=[37700], test_mask=[37700])
#
# training samples 3770
# validation samples 11310
# test samples 22620

# %%
class SocialGNN(torch.nn.Module):
    def __init__(self,num_of_feat,f):
        super(SocialGNN, self).__init__()


        self.conv1 = GCNConv(num_of_feat, f)

        self.conv2 = GCNConv(f, 2)


    def forward(self, data):
        x = data.x.float()
        edge_index =  data.edge_index
          
        x = self.conv1(x=x, edge_index=edge_index)
        x = F.relu(x)

        x = self.conv2(x, edge_index)
        return x

# %%
def masked_loss(predictions,labels,mask):
    mask=mask.float()
    mask=mask/torch.mean(mask)
    loss=criterion(predictions,labels)
    loss=loss*mask
    loss=torch.mean(loss)
    return (loss)

# %%
def masked_accuracy(predictions,labels,mask):
    mask=mask.float()
    mask/=torch.mean(mask)
    accuracy=(torch.argmax(predictions,axis=1)==labels).long()
    accuracy=mask*accuracy
    accuracy=torch.mean(accuracy)
    return (accuracy)

# %%
def train_social(net,data,epochs=10,lr=0.01):
    optimizer = torch.optim.Adam(net.parameters(), lr=lr) # 00001
    best_accuracy=0.0
    
    train_losses=[]
    train_accuracies=[]

    val_losses=[]
    val_accuracies=[]

    test_losses=[]
    test_accuracies=[]
    
    for ep in range(epochs+1):
        optimizer.zero_grad()
        out=net(data)
        loss=masked_loss(predictions=out,
                         labels=data.y,
                         mask=data.train_mask)
        loss.backward()
        optimizer.step()
        train_losses+=[loss]
        train_accuracy=masked_accuracy(predictions=out,
                                       labels=data.y, 
                                       mask=data.train_mask)
        train_accuracies+=[train_accuracy]
        
        val_loss=masked_loss(predictions=out,
                             labels=data.y, 
                             mask=data.val_mask)
        val_losses+=[val_loss]
        
        val_accuracy=masked_accuracy(predictions=out,
                                     labels=data.y, 
                                     mask=data.val_mask)
        val_accuracies+=[val_accuracy]

        test_accuracy=masked_accuracy(predictions=out,
                                      labels=data.y, 
                                      mask=data.test_mask)
        test_accuracies+=[test_accuracy]
        if np.round(val_accuracy,4)> np.round(best_accuracy ,4):
            print("Epoch {}/{}, Train_Loss: {:.4f}, Train_Accuracy: {:.4f}, Val_Accuracy: {:.4f}, Test_Accuracy: {:.4f}"
                      .format(ep+1,epochs, loss.item(), train_accuracy, val_accuracy,  test_accuracy))
            best_accuracy=val_accuracy

  

    
    plt.plot(train_accuracies) 
    plt.plot(val_accuracies)
    plt.plot(test_accuracies) 
    plt.show()
    
    print("Best accuracy",best_accuracy) 
    return(best_accuracy)

# %%
num_of_feat=g.num_node_features
net=SocialGNN(num_of_feat=num_of_feat,f=16)
criterion=nn.CrossEntropyLoss()
train_social(net,g,epochs=150,lr=0.1)
# Out:
# Epoch 1/150, Train_Loss: 0.7139, Train_Accuracy: 0.2528, Val_Accuracy: 0.2624, Test_Accuracy: 0.2608
# Epoch 2/150, Train_Loss: 0.8739, Train_Accuracy: 0.7496, Val_Accuracy: 0.7398, Test_Accuracy: 0.7414
# Epoch 3/150, Train_Loss: 0.4762, Train_Accuracy: 0.7496, Val_Accuracy: 0.7401, Test_Accuracy: 0.7415
# Epoch 4/150, Train_Loss: 0.5583, Train_Accuracy: 0.7499, Val_Accuracy: 0.7403, Test_Accuracy: 0.7416
# Epoch 5/150, Train_Loss: 0.5598, Train_Accuracy: 0.7504, Val_Accuracy: 0.7406, Test_Accuracy: 0.7425
# Epoch 6/150, Train_Loss: 0.5183, Train_Accuracy: 0.7512, Val_Accuracy: 0.7412, Test_Accuracy: 0.7435
# Epoch 7/150, Train_Loss: 0.4692, Train_Accuracy: 0.7523, Val_Accuracy: 0.7435, Test_Accuracy: 0.7460
# Epoch 8/150, Train_Loss: 0.4419, Train_Accuracy: 0.7615, Val_Accuracy: 0.7521, Test_Accuracy: 0.7553
# Epoch 9/150, Train_Loss: 0.4252, Train_Accuracy: 0.7944, Val_Accuracy: 0.7830, Test_Accuracy: 0.7865
# Epoch 10/150, Train_Loss: 0.3860, Train_Accuracy: 0.8414, Val_Accuracy: 0.8336, Test_Accuracy: 0.8344
# Epoch 11/150, Train_Loss: 0.3672, Train_Accuracy: 0.8692, Val_Accuracy: 0.8576, Test_Accuracy: 0.8646
# Epoch 12/150, Train_Loss: 0.3968, Train_Accuracy: 0.8626, Val_Accuracy: 0.8591, Test_Accuracy: 0.8636
# Epoch 13/150, Train_Loss: 0.3730, Train_Accuracy: 0.8687, Val_Accuracy: 0.8596, Test_Accuracy: 0.8672
# Epoch 14/150, Train_Loss: 0.3476, Train_Accuracy: 0.8735, Val_Accuracy: 0.8597, Test_Accuracy: 0.8683
# Epoch 17/150, Train_Loss: 0.3281, Train_Accuracy: 0.8740, Val_Accuracy: 0.8610, Test_Accuracy: 0.8682
# Epoch 18/150, Train_Loss: 0.3264, Train_Accuracy: 0.8767, Val_Accuracy: 0.8660, Test_Accuracy: 0.8716
# Epoch 19/150, Train_Loss: 0.3324, Train_Accuracy: 0.8761, Val_Accuracy: 0.8665, Test_Accuracy: 0.8728
# Epoch 20/150, Train_Loss: 0.3284, Train_Accuracy: 0.8767, Val_Accuracy: 0.8688, Test_Accuracy: 0.8733
# Epoch 25/150, Train_Loss: 0.3092, Train_Accuracy: 0.8796, Val_Accuracy: 0.8706, Test_Accuracy: 0.8761
# Epoch 27/150, Train_Loss: 0.3106, Train_Accuracy: 0.8788, Val_Accuracy: 0.8721, Test_Accuracy: 0.8776
# Epoch 28/150, Train_Loss: 0.3060, Train_Accuracy: 0.8806, Val_Accuracy: 0.8741, Test_Accuracy: 0.8779
# Epoch 31/150, Train_Loss: 0.3003, Train_Accuracy: 0.8817, Val_Accuracy: 0.8745, Test_Accuracy: 0.8788
# Epoch 32/150, Train_Loss: 0.2978, Train_Accuracy: 0.8833, Val_Accuracy: 0.8759, Test_Accuracy: 0.8807
# Epoch 33/150, Train_Loss: 0.2980, Train_Accuracy: 0.8814, Val_Accuracy: 0.8773, Test_Accuracy: 0.8821
# Epoch 34/150, Train_Loss: 0.2958, Train_Accuracy: 0.8830, Val_Accuracy: 0.8775, Test_Accuracy: 0.8826
# Epoch 37/150, Train_Loss: 0.2920, Train_Accuracy: 0.8857, Val_Accuracy: 0.8778, Test_Accuracy: 0.8821
# Epoch 38/150, Train_Loss: 0.2892, Train_Accuracy: 0.8873, Val_Accuracy: 0.8806, Test_Accuracy: 0.8839
# Epoch 39/150, Train_Loss: 0.2881, Train_Accuracy: 0.8865, Val_Accuracy: 0.8821, Test_Accuracy: 0.8849
# Epoch 40/150, Train_Loss: 0.2870, Train_Accuracy: 0.8857, Val_Accuracy: 0.8830, Test_Accuracy: 0.8856
# Epoch 44/150, Train_Loss: 0.2810, Train_Accuracy: 0.8883, Val_Accuracy: 0.8844, Test_Accuracy: 0.8861
# Epoch 45/150, Train_Loss: 0.2804, Train_Accuracy: 0.8859, Val_Accuracy: 0.8859, Test_Accuracy: 0.8873
# Epoch 46/150, Train_Loss: 0.2789, Train_Accuracy: 0.8878, Val_Accuracy: 0.8864, Test_Accuracy: 0.8881
# Epoch 48/150, Train_Loss: 0.2766, Train_Accuracy: 0.8910, Val_Accuracy: 0.8866, Test_Accuracy: 0.8880
# Epoch 49/150, Train_Loss: 0.2750, Train_Accuracy: 0.8905, Val_Accuracy: 0.8872, Test_Accuracy: 0.8897
# Epoch 50/150, Train_Loss: 0.2741, Train_Accuracy: 0.8897, Val_Accuracy: 0.8884, Test_Accuracy: 0.8905
# Epoch 52/150, Train_Loss: 0.2718, Train_Accuracy: 0.8899, Val_Accuracy: 0.8888, Test_Accuracy: 0.8903
# Epoch 53/150, Train_Loss: 0.2710, Train_Accuracy: 0.8912, Val_Accuracy: 0.8890, Test_Accuracy: 0.8894
# Epoch 54/150, Train_Loss: 0.2696, Train_Accuracy: 0.8899, Val_Accuracy: 0.8891, Test_Accuracy: 0.8906
# Epoch 55/150, Train_Loss: 0.2688, Train_Accuracy: 0.8907, Val_Accuracy: 0.8901, Test_Accuracy: 0.8916
# Epoch 58/150, Train_Loss: 0.2655, Train_Accuracy: 0.8923, Val_Accuracy: 0.8904, Test_Accuracy: 0.8913
# Epoch 59/150, Train_Loss: 0.2645, Train_Accuracy: 0.8923, Val_Accuracy: 0.8910, Test_Accuracy: 0.8927
# Epoch 61/150, Train_Loss: 0.2625, Train_Accuracy: 0.8942, Val_Accuracy: 0.8913, Test_Accuracy: 0.8927
# Epoch 62/150, Train_Loss: 0.2615, Train_Accuracy: 0.8942, Val_Accuracy: 0.8920, Test_Accuracy: 0.8929
# Epoch 63/150, Train_Loss: 0.2606, Train_Accuracy: 0.8950, Val_Accuracy: 0.8925, Test_Accuracy: 0.8938
# Epoch 64/150, Train_Loss: 0.2596, Train_Accuracy: 0.8952, Val_Accuracy: 0.8934, Test_Accuracy: 0.8939
# Epoch 65/150, Train_Loss: 0.2588, Train_Accuracy: 0.8966, Val_Accuracy: 0.8941, Test_Accuracy: 0.8941
# Epoch 66/150, Train_Loss: 0.2577, Train_Accuracy: 0.8963, Val_Accuracy: 0.8946, Test_Accuracy: 0.8950
# Epoch 67/150, Train_Loss: 0.2570, Train_Accuracy: 0.8958, Val_Accuracy: 0.8949, Test_Accuracy: 0.8950
# Epoch 68/150, Train_Loss: 0.2560, Train_Accuracy: 0.8981, Val_Accuracy: 0.8958, Test_Accuracy: 0.8956
# Epoch 69/150, Train_Loss: 0.2551, Train_Accuracy: 0.8984, Val_Accuracy: 0.8964, Test_Accuracy: 0.8958
# Epoch 72/150, Train_Loss: 0.2526, Train_Accuracy: 0.8989, Val_Accuracy: 0.8972, Test_Accuracy: 0.8974
# Epoch 75/150, Train_Loss: 0.2501, Train_Accuracy: 0.8984, Val_Accuracy: 0.8974, Test_Accuracy: 0.8983
# Epoch 77/150, Train_Loss: 0.2485, Train_Accuracy: 0.8995, Val_Accuracy: 0.8979, Test_Accuracy: 0.8993
# Epoch 79/150, Train_Loss: 0.2470, Train_Accuracy: 0.9003, Val_Accuracy: 0.8986, Test_Accuracy: 0.9004
# Epoch 81/150, Train_Loss: 0.2455, Train_Accuracy: 0.9005, Val_Accuracy: 0.8989, Test_Accuracy: 0.9012
# Epoch 83/150, Train_Loss: 0.2440, Train_Accuracy: 0.9011, Val_Accuracy: 0.8990, Test_Accuracy: 0.9016
# Epoch 84/150, Train_Loss: 0.2433, Train_Accuracy: 0.9013, Val_Accuracy: 0.8994, Test_Accuracy: 0.9023
# Epoch 85/150, Train_Loss: 0.2426, Train_Accuracy: 0.9029, Val_Accuracy: 0.8998, Test_Accuracy: 0.9016
# Epoch 86/150, Train_Loss: 0.2419, Train_Accuracy: 0.9005, Val_Accuracy: 0.9003, Test_Accuracy: 0.9034
# Epoch 88/150, Train_Loss: 0.2408, Train_Accuracy: 0.9019, Val_Accuracy: 0.9007, Test_Accuracy: 0.9044
# Epoch 90/150, Train_Loss: 0.2415, Train_Accuracy: 0.9003, Val_Accuracy: 0.9009, Test_Accuracy: 0.9046
# Epoch 94/150, Train_Loss: 0.2372, Train_Accuracy: 0.9032, Val_Accuracy: 0.9028, Test_Accuracy: 0.9059
# Epoch 100/150, Train_Loss: 0.2348, Train_Accuracy: 0.9045, Val_Accuracy: 0.9031, Test_Accuracy: 0.9071
# Epoch 101/150, Train_Loss: 0.2332, Train_Accuracy: 0.9061, Val_Accuracy: 0.9036, Test_Accuracy: 0.9074
# Epoch 104/150, Train_Loss: 0.2312, Train_Accuracy: 0.9069, Val_Accuracy: 0.9056, Test_Accuracy: 0.9080
# Epoch 113/150, Train_Loss: 0.2264, Train_Accuracy: 0.9085, Val_Accuracy: 0.9058, Test_Accuracy: 0.9101
# Epoch 114/150, Train_Loss: 0.2263, Train_Accuracy: 0.9098, Val_Accuracy: 0.9063, Test_Accuracy: 0.9101
# Epoch 120/150, Train_Loss: 0.2236, Train_Accuracy: 0.9098, Val_Accuracy: 0.9065, Test_Accuracy: 0.9111
# Epoch 121/150, Train_Loss: 0.2226, Train_Accuracy: 0.9130, Val_Accuracy: 0.9080, Test_Accuracy: 0.9120
# Epoch 124/150, Train_Loss: 0.2211, Train_Accuracy: 0.9138, Val_Accuracy: 0.9084, Test_Accuracy: 0.9126
# Epoch 131/150, Train_Loss: 0.2184, Train_Accuracy: 0.9114, Val_Accuracy: 0.9091, Test_Accuracy: 0.9139
# Epoch 135/150, Train_Loss: 0.2162, Train_Accuracy: 0.9114, Val_Accuracy: 0.9103, Test_Accuracy: 0.9150
# Epoch 139/150, Train_Loss: 0.2146, Train_Accuracy: 0.9146, Val_Accuracy: 0.9111, Test_Accuracy: 0.9158
# Epoch 143/150, Train_Loss: 0.2126, Train_Accuracy: 0.9133, Val_Accuracy: 0.9115, Test_Accuracy: 0.9164
# Epoch 145/150, Train_Loss: 0.2142, Train_Accuracy: 0.9133, Val_Accuracy: 0.9116, Test_Accuracy: 0.9149
# Epoch 147/150, Train_Loss: 0.2121, Train_Accuracy: 0.9149, Val_Accuracy: 0.9123, Test_Accuracy: 0.9162
# Epoch 149/150, Train_Loss: 0.2100, Train_Accuracy: 0.9146, Val_Accuracy: 0.9129, Test_Accuracy: 0.9175
# Epoch 150/150, Train_Loss: 0.2103, Train_Accuracy: 0.9149, Val_Accuracy: 0.9130, Test_Accuracy: 0.9173
# Best accuracy tensor(0.9130)
# tensor(0.9130)
